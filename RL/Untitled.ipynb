# %%
import matplotlib.pyplot as plt

# %%
plt.plot([(i,i) for i in range(20)])

# %%
res = [[0.5, 0.5], [0.4, 0.4], [0.30000000000000004, 0.5], [0.4, 0.6], [0.30000000000000004, 0.7], [0.4, 0.7999999999999999], [0.5, 0.7], [0.4, 0.7999999999999999], [0.30000000000000004, 0.7], [0.4, 0.7999999999999999], [0.5, 0.8999999999999999]]

# %%
plt.plot([i for i,j in res ],[j for i,j in res ])

# %%
[i for i,j in res ]
# Out:
# [0.5,
#  0.4,
#  0.30000000000000004,
#  0.4,
#  0.30000000000000004,
#  0.4,
#  0.5,
#  0.4,
#  0.30000000000000004,
#  0.4,
#  0.5]
